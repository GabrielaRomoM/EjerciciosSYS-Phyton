# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielaRomoM/EjerciciosSYS-Python/blob/main/3FOURIER/1Fourier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EJERCICIO 1: Presente una simulación relacionada con la proyección lineal de (a) pertenece a R2 sobre (b) pertenece a R2. El código debe permitir al usuario ingresar las componentes de los dos vectores, calcular el factor de escala de la proyección y graficar los vectores de entrada y el proyectado (usar la función pyplot.arrow).

# %%
84
5

import matplotlib.pyplot as plt
from matplotlib import *
import numpy as np

def proy(a,b):
  pp=0
  for i in range(0,len(a)):
      pp=pp+(a[i]*b[i])
  return pp

a=[]
b=[]
c=[]
print("Ingrese los puntos del vector a: ")
for i in range(0,2):
  a.append(float(input("")))

print("Ingrese los puntos del vector b: ")
for i in range(0,2):
  b.append(float(input("")))

ProdPun=proy(a,b) #Producto punto
NB=(np.linalg.norm(b))**2 #NB es la norma del vector, se llama a un comando predefinido incluido en Numpy

Proyeccion=(ProdPun/NB)
for i in range(0,2):
  c.append(Proyeccion*b[i])

print("El factor de escala de la proyeccion es:",round(Proyeccion,2))
print()
plt.figure()
plt.grid()
plt.arrow(0,0,a[0],a[1],color='green',label='Vector a',linewidth=2)
plt.arrow(0,0,b[0],b[1],color='red',label='Vector b',linewidth=6)
plt.arrow(0,0,c[0],c[1],color='blue',label='Vector Proyeccion',linewidth=2)
plt.legend()
plt.show()
# Out:
# Ingrese los puntos del vector a:
# 1
# 2
# Ingrese los puntos del vector b:
# 3
# 4
# El factor de escala de la proyeccion es: 0.44

# %% [markdown]
# Encontrar la representación por serie exponencial de Fourier de la señal  x(t)=Arectτ/2(t) , con  t∈[−τ/2,τ/2] . Graficar el espectro, la fase del espectro, la reconstrucción para  n∈{0,±1,±2,…} , y determinar el valor del error relativo para cada valor de  n . Utilice el ambiente animación de Python para mostrar los resultados.
